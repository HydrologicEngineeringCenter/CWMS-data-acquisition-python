# %%
#libraries
import pandas as pd
from datetime import datetime, timedelta
import cwms
from dataretrieval import nwis
import requests
from json import loads

# %%
apiRoot = "https://cwms-data-test.cwbi.us/cwms-data/"
#apiRoot = "https://wm.mvp.ds.usace.army.mil:8243/mvp-data/"
from getpass import getpass
apiKey = "apikey " + getpass()
api = cwms.api.init_session(api_root=apiRoot, api_key=apiKey)
# Out:
#  ········

# %%
def get_rating_ids_from_specs(office_id):
    rating_types = ['EXSA', 'CORR', 'BASE']
    #templates = ['Stage;Flow.USGS-BASE', 'Stage;Flow.USGS-EXSA', 'Stage;Stage.USGS-CORR']
    rating_specs = cwms.get_rating_specs(office_id=office_id).df
    #rating_specs = rating_specs[rating_specs['template-id'].isin(templates)]
    rating_specs = rating_specs.dropna(subset=['description'])
    for rating_type in rating_types:
        rating_specs.loc[rating_specs['description'].str.contains(f'USGS-{rating_type}'), 'rating-type'] = rating_type
    rating_specs = rating_specs[(
        rating_specs['rating-type'].isin(rating_types)) & 
        (rating_specs['active']==True) & 
        (rating_specs['auto-update']==True)]
    return rating_specs

# %%
def get_rating_ids_from_template(template_id_mask:str, office_id:str = None):
    templates = cwms.get_rating_templates(template_id_mask=template_id_mask,office_id=office_id).df
    rating_specs = pd.DataFrame()
    for _, template in templates.iterrows():
        rating_ids = pd.DataFrame(template['rating-ids'])
        if not rating_ids.empty:
            rating_ids.columns = ["rating-id"]
            exp_ids = rating_ids['rating-id'].str.split('.',expand=True)
            exp_ids.columns = ["location-id","template-params","template-version","spec-version"]
            rating_spec = pd.concat([rating_ids,exp_ids],axis=1)
            rating_spec = rating_spec.assign(**{"office-id":template["office-id"],"template-id":template["id"]})
            rating_specs = pd.concat([rating_specs, rating_spec], ignore_index=True)
    return rating_specs

# %%
#rating_specs = get_rating_ids_from_template("Stage;Flow.EXSA","LRL")
#rating_specs = get_rating_ids_from_template(template_id_mask="*.USGS-*")
rating_specs = get_rating_ids_from_specs('MVP')

# %%
def get_location_aliases(df, loc_group_id, category_id, office_id):
    Locdf = cwms.get_location_group(loc_group_id=loc_group_id,category_id=category_id,office_id=office_id).df
    USGS_alias = Locdf[Locdf['alias-id'].notnull()]
    USGS_alias = USGS_alias.rename(columns = {'alias-id': 'USGS_St_Num','attribute':'Loc_attribute'})
    USGS_alias.USGS_St_Num = USGS_alias.USGS_St_Num.str.rjust(8,'0')
    USGS_ratings = pd.merge(df, USGS_alias,  how='inner', on=['location-id','office-id'])
    return USGS_ratings

# %%
USGS_ratings = get_location_aliases(rating_specs,"USGS Station Number","Agency Aliases","CWMS")

# %%
USGS_ratings
# Out:
#     office-id                                   rating-id  \
# 0         MVP        ABRN8.Stage;Flow.USGS-BASE.USGS-NWIS
# 1         MVP        ABRN8.Stage;Flow.USGS-EXSA.USGS-NWIS
# 2         MVP       ABRN8.Stage;Stage.USGS-CORR.USGS-NWIS
# 3         MVP        AGYM5.Stage;Flow.USGS-BASE.USGS-NWIS
# 4         MVP        AGYM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# ..        ...                                         ...
# 333       MVP    Westhope.Stage;Stage.USGS-CORR.USGS-NWIS
# 334       MVP   WillowCity.Stage;Flow.USGS-EXSA.USGS-NWIS
# 335       MVP  WillowCity.Stage;Stage.USGS-CORR.USGS-NWIS
# 336       MVP        ZUMM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# 337       MVP       ZUMM5.Stage;Stage.USGS-CORR.USGS-NWIS
#
#                template-id location-id    version in-range-method  \
# 0     Stage;Flow.USGS-BASE       ABRN8  USGS-NWIS          LINEAR
# 1     Stage;Flow.USGS-EXSA       ABRN8  USGS-NWIS          LINEAR
# 2    Stage;Stage.USGS-CORR       ABRN8  USGS-NWIS          LINEAR
# 3     Stage;Flow.USGS-BASE       AGYM5  USGS-NWIS          LINEAR
# 4     Stage;Flow.USGS-EXSA       AGYM5  USGS-NWIS          LINEAR
# ..                     ...         ...        ...             ...
# 333  Stage;Stage.USGS-CORR    Westhope  USGS-NWIS          LINEAR
# 334   Stage;Flow.USGS-EXSA  WillowCity  USGS-NWIS          LINEAR
# 335  Stage;Stage.USGS-CORR  WillowCity  USGS-NWIS          LINEAR
# 336   Stage;Flow.USGS-EXSA       ZUMM5  USGS-NWIS          LINEAR
# 337  Stage;Stage.USGS-CORR       ZUMM5  USGS-NWIS          LINEAR
#
#     out-range-low-method out-range-high-method  active  auto-update  \
# 0                NEAREST               NEAREST    True         True
# 1                NEAREST               NEAREST    True         True
# 2                NEAREST               NEAREST    True         True
# 3                NEAREST               NEAREST    True         True
# 4                NEAREST               NEAREST    True         True
# ..                   ...                   ...     ...          ...
# 333              NEAREST               NEAREST    True         True
# 334              NEAREST               NEAREST    True         True
# 335              NEAREST               NEAREST    True         True
# 336              NEAREST               NEAREST    True         True
# 337              NEAREST               NEAREST    True         True
#
#      auto-activate  auto-migrate-extension independent-rounding-specs  \
# 0             True                    True  [{'value': '2223456782'}]
# 1             True                    True  [{'value': '2223456782'}]
# 2             True                    True  [{'value': '4444444444'}]
# 3             True                    True  [{'value': '2223456782'}]
# 4             True                    True  [{'value': '2223456782'}]
# ..             ...                     ...                        ...
# 333           True                    True  [{'value': '4444444444'}]
# 334           True                    True  [{'value': '2223456782'}]
# 335           True                    True  [{'value': '4444444444'}]
# 336           True                    True  [{'value': '2223456782'}]
# 337           True                    True  [{'value': '4444444444'}]
#
#     dependent-rounding-spec  \
# 0                2222233332
# 1                2222233332
# 2                4444444444
# 3                2222233332
# 4                2222233332
# ..                      ...
# 333              4444444444
# 334              2222233332
# 335              4444444444
# 336              2222233332
# 337              4444444444
#
#                                        effective-dates source-agency  \
# 0    [2012-09-12T05:00:00Z, 2012-09-12T05:00:00Z, 2...           NaN
# 1    [2014-11-04T21:15:00Z, 2014-11-04T21:15:00Z, 2...           NaN
# 2    [2014-11-04T21:10:00Z, 2014-11-04T21:10:00Z, 2...           NaN
# 3    [2012-10-13T05:00:00Z, 2012-10-13T05:00:00Z, 2...           NaN
# 4    [2014-10-17T15:48:00Z, 2014-10-17T15:48:00Z, 2...           NaN
# ..                                                 ...           ...
# 333  [2017-01-18T19:30:00Z, 2017-01-18T19:30:00Z, 2...           NaN
# 334  [2010-03-01T06:00:00Z, 2010-03-01T06:00:00Z, 2...           NaN
# 335  [2015-03-18T18:15:00Z, 2015-03-18T18:15:00Z, 2...           NaN
# 336  [2013-01-01T21:58:00Z, 2013-01-01T21:58:00Z, 2...           NaN
# 337  [2012-10-10T18:55:00Z, 2012-10-10T18:55:00Z, 2...           NaN
#
#                                            description rating-type  \
# 0    WILD RICE RIVER NR ABERCROMBIE, ND USGS-NWIS S...        BASE
# 1    WILD RICE RIVER NR ABERCROMBIE, ND Expanded, S...        EXSA
# 2    WILD RICE RIVER NR ABERCROMBIE, ND Stage Corre...        CORR
# 3    MIDDLE RIVER AT ARGYLE, MN USGS-NWIS Stream Ra...        BASE
# 4    MIDDLE RIVER AT ARGYLE, MN Expanded, Shift-Adj...        EXSA
# ..                                                 ...         ...
# 333  SOURIS RIVER NR WESTHOPE, ND Stage Correction ...        CORR
# 334  WILLOW CREEK NR WILLOW CITY, ND Expanded, Shif...        EXSA
# 335  WILLOW CREEK NR WILLOW CITY, ND Stage Correcti...        CORR
# 336  ZUMBRO RIVER AT ZUMBRO FALLS, MN Expanded, Shi...        EXSA
# 337  ZUMBRO RIVER AT ZUMBRO FALLS, MN Stage Correct...        CORR
#
#     USGS_St_Num  Loc_attribute
# 0      05053000            0.0
# 1      05053000            0.0
# 2      05053000            0.0
# 3      05087500            0.0
# 4      05087500            0.0
# ..          ...            ...
# 333    05124000            0.0
# 334    05123400            0.0
# 335    05123400            0.0
# 336    05374000            0.0
# 337    05374000            0.0
#
# [338 rows x 20 columns]

# %%
USGS_ratings_empty = USGS_ratings[USGS_ratings['effective-dates'].isna()]

# %%
USGS_ratings = USGS_ratings[USGS_ratings['effective-dates'].notna()]

# %%
def get_usgs_updated_ratings(period):
    '''
    Function to grab data from the USGS based off of dataretieve-python
    ''' 
    # Get USGS data
    base_url = "https://nwis.waterdata.usgs.gov/nwisweb/get_ratings"

    query_dict = {
        "period":period,
        "format": "rdb"
    }

    r = requests.get(base_url, params = query_dict)
    temp = pd.DataFrame(r.text.split('\n'))
    temp = temp[temp[0].str.startswith("USGS")]
    updated_ratings = temp[0].str.split("\t",expand=True)
    updated_ratings.columns = ["org","USGS_St_Num","rating-type","date_updated","url"]
    updated_ratings["rating-type"] = updated_ratings["rating-type"].str.upper()
    return updated_ratings

# %%
df = get_usgs_updated_ratings(48)

# %%
updated_ratings = pd.merge(USGS_ratings, df, how='inner', left_on=['USGS_St_Num','rating-type'],right_on=['USGS_St_Num','rating-type'])

# %%
updated_ratings.loc[:,'effective-dates'] = updated_ratings['effective-dates'].apply(lambda x: [pd.to_datetime(d) for d in x])
updated_ratings.loc[:,'cwms_max_effective_date'] = updated_ratings['effective-dates'].apply(max)

# %%
if not USGS_ratings_empty.empty:
    updated_ratings = pd.concat([updated_ratings, USGS_ratings_empty],ignore_index=True)

# %%
updated_ratings
# Out:
#    office-id                                          rating-id  \
# 0        MVP               AGYM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# 1        MVP              AGYM5.Stage;Stage.USGS-CORR.USGS-NWIS
# 2        MVP               BRMN8.Stage;Flow.USGS-EXSA.USGS-NWIS
# 3        MVP              BRMN8.Stage;Stage.USGS-CORR.USGS-NWIS
# 4        MVP              DBCN8.Stage;Stage.USGS-CORR.USGS-NWIS
# 5        MVP               DDGW3.Stage;Flow.USGS-EXSA.USGS-NWIS
# 6        MVP              DDGW3.Stage;Stage.USGS-CORR.USGS-NWIS
# 7        MVP               FSHM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# 8        MVP              FSHM5.Stage;Stage.USGS-CORR.USGS-NWIS
# 9        MVP               HRCN8.Stage;Flow.USGS-EXSA.USGS-NWIS
# 10       MVP              HRCN8.Stage;Stage.USGS-CORR.USGS-NWIS
# 11       MVP               HUSM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# 12       MVP               LKBM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# 13       MVP              LKBM5.Stage;Stage.USGS-CORR.USGS-NWIS
# 14       MVP  Orwell_Dam-Tailwater.Stage;Flow.USGS-EXSA.USGS...
# 15       MVP  Orwell_Dam-Tailwater.Stage;Stage.USGS-CORR.USG...
# 16       MVP               SRGM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# 17       MVP              SRGM5.Stage;Stage.USGS-CORR.USGS-NWIS
# 18       MVP               WFON8.Stage;Flow.USGS-EXSA.USGS-NWIS
# 19       MVP              WFON8.Stage;Stage.USGS-CORR.USGS-NWIS
#
#               template-id           location-id    version in-range-method  \
# 0    Stage;Flow.USGS-EXSA                 AGYM5  USGS-NWIS          LINEAR
# 1   Stage;Stage.USGS-CORR                 AGYM5  USGS-NWIS          LINEAR
# 2    Stage;Flow.USGS-EXSA                 BRMN8  USGS-NWIS          LINEAR
# 3   Stage;Stage.USGS-CORR                 BRMN8  USGS-NWIS          LINEAR
# 4   Stage;Stage.USGS-CORR                 DBCN8  USGS-NWIS          LINEAR
# 5    Stage;Flow.USGS-EXSA                 DDGW3  USGS-NWIS          LINEAR
# 6   Stage;Stage.USGS-CORR                 DDGW3  USGS-NWIS          LINEAR
# 7    Stage;Flow.USGS-EXSA                 FSHM5  USGS-NWIS          LINEAR
# 8   Stage;Stage.USGS-CORR                 FSHM5  USGS-NWIS          LINEAR
# 9    Stage;Flow.USGS-EXSA                 HRCN8  USGS-NWIS          LINEAR
# 10  Stage;Stage.USGS-CORR                 HRCN8  USGS-NWIS          LINEAR
# 11   Stage;Flow.USGS-EXSA                 HUSM5  USGS-NWIS          LINEAR
# 12   Stage;Flow.USGS-EXSA                 LKBM5  USGS-NWIS          LINEAR
# 13  Stage;Stage.USGS-CORR                 LKBM5  USGS-NWIS          LINEAR
# 14   Stage;Flow.USGS-EXSA  Orwell_Dam-Tailwater  USGS-NWIS          LINEAR
# 15  Stage;Stage.USGS-CORR  Orwell_Dam-Tailwater  USGS-NWIS          LINEAR
# 16   Stage;Flow.USGS-EXSA                 SRGM5  USGS-NWIS          LINEAR
# 17  Stage;Stage.USGS-CORR                 SRGM5  USGS-NWIS          LINEAR
# 18   Stage;Flow.USGS-EXSA                 WFON8  USGS-NWIS          LINEAR
# 19  Stage;Stage.USGS-CORR                 WFON8  USGS-NWIS          LINEAR
#
#    out-range-low-method out-range-high-method  active  auto-update  ...  \
# 0               NEAREST               NEAREST    True         True  ...
# 1               NEAREST               NEAREST    True         True  ...
# 2               NEAREST               NEAREST    True         True  ...
# 3               NEAREST               NEAREST    True         True  ...
# 4               NEAREST               NEAREST    True         True  ...
# 5               NEAREST               NEAREST    True         True  ...
# 6               NEAREST               NEAREST    True         True  ...
# 7               NEAREST               NEAREST    True         True  ...
# 8               NEAREST               NEAREST    True         True  ...
# 9               NEAREST               NEAREST    True         True  ...
# 10              NEAREST               NEAREST    True         True  ...
# 11              NEAREST               NEAREST    True         True  ...
# 12              NEAREST               NEAREST    True         True  ...
# 13              NEAREST               NEAREST    True         True  ...
# 14              NEAREST               NEAREST    True         True  ...
# 15              NEAREST               NEAREST    True         True  ...
# 16              NEAREST               NEAREST    True         True  ...
# 17              NEAREST               NEAREST    True         True  ...
# 18              NEAREST               NEAREST    True         True  ...
# 19              NEAREST               NEAREST    True         True  ...
#
#                                       effective-dates  source-agency  \
# 0   [2014-10-17 15:48:00+00:00, 2014-10-17 15:48:0...            NaN
# 1   [2014-10-17 15:48:00+00:00, 2014-10-17 15:48:0...            NaN
# 2   [2014-04-21 21:52:00+00:00, 2014-04-21 21:52:0...            NaN
# 3   [2014-10-07 16:30:00+00:00, 2014-10-07 16:30:0...            NaN
# 4   [2014-10-30 14:30:00+00:00, 2014-10-30 14:30:0...            NaN
# 5   [2015-09-03 19:59:00+00:00, 2015-09-03 19:59:0...            NaN
# 6   [2015-10-08 14:50:00+00:00, 2015-10-08 14:50:0...            NaN
# 7   [2014-08-11 19:05:00+00:00, 2014-08-11 19:05:0...            NaN
# 8   [2014-08-11 19:05:00+00:00, 2014-08-11 19:05:0...            NaN
# 9   [2014-10-22 14:00:00+00:00, 2014-10-22 14:00:0...            NaN
# 10  [2014-10-22 13:30:00+00:00, 2014-10-22 13:30:0...            NaN
# 11  [2015-08-20 17:01:00+00:00, 2015-08-20 17:01:0...            NaN
# 12  [2014-10-17 14:45:00+00:00, 2014-10-17 14:45:0...            NaN
# 13  [2013-05-07 15:06:00+00:00, 2013-05-07 15:06:0...            NaN
# 14  [2014-11-06 17:34:00+00:00, 2014-11-06 17:34:0...            NaN
# 15  [2015-01-07 22:11:00+00:00, 2015-01-07 22:11:0...            NaN
# 16  [2014-12-10 20:07:00+00:00, 2014-12-10 20:07:0...            NaN
# 17  [2014-12-10 20:34:00+00:00, 2014-12-10 20:34:0...            NaN
# 18  [2014-11-03 21:40:00+00:00, 2014-11-03 21:40:0...            NaN
# 19  [2014-11-03 20:45:00+00:00, 2014-11-03 20:45:0...            NaN
#
#                                           description rating-type USGS_St_Num  \
# 0   MIDDLE RIVER AT ARGYLE, MN Expanded, Shift-Adj...        EXSA    05087500
# 1   MIDDLE RIVER AT ARGYLE, MN Stage Correction US...        CORR    05087500
# 2   SHEYENNE R BL DEVILS LK STATE OUTLET NR BREMEN...        EXSA    05055400
# 3   SHEYENNE R BL DEVILS LK STATE OUTLET NR BREMEN...        CORR    05055400
# 4   BALDHILL CREEK NR DAZEY, ND Stage Correction U...        CORR    05057200
# 5   TREMPEALEAU RIVER AT DODGE, WI Expanded, Shift...        EXSA    05379500
# 6   TREMPEALEAU RIVER AT DODGE, WI Stage Correctio...        CORR    05379500
# 7   RED LAKE RIVER AT FISHER, MN Expanded, Shift-A...        EXSA    05080000
# 8   RED LAKE RIVER AT FISHER, MN Stage Correction ...        CORR    05080000
# 9   SHEYENNE R AB SHEYENNE R DIVERSION NR HORACE, ...        EXSA    05059300
# 10  SHEYENNE R AB SHEYENNE R DIVERSION NR HORACE, ...        CORR    05059300
# 11  SOUTH FORK ROOT RIVER NEAR HOUSTON, MN Expande...        EXSA    05385500
# 12  SOUTH BRANCH TWO RIVERS AT LAKE BRONSON, MN Ex...        EXSA    05094000
# 13  SOUTH BRANCH TWO RIVERS AT LAKE BRONSON, MN St...        CORR    05094000
# 14  OTTER TAIL RIVER BL ORWELL D NR FERGUS FALLS, ...        EXSA    05046000
# 15  OTTER TAIL RIVER BL ORWELL D NR FERGUS FALLS, ...        CORR    05046000
# 16  SPRAGUE CREEK NEAR SPRAGUE, MANITOBA, CANADA E...        EXSA    05106000
# 17  SPRAGUE CREEK NEAR SPRAGUE, MANITOBA, CANADA S...        CORR    05106000
# 18  SHEYENNE RIVER DIVERSION AT WEST FARGO, ND Exp...        EXSA    05059480
# 19  SHEYENNE RIVER DIVERSION AT WEST FARGO, ND Sta...        CORR    05059480
#
#    Loc_attribute   org         date_updated  \
# 0            0.0  USGS  2024-10-30 16:52:41
# 1            0.0  USGS  2024-10-30 16:52:41
# 2            0.0  USGS  2024-10-31 15:36:37
# 3            0.0  USGS  2024-10-31 15:36:37
# 4            0.0  USGS  2024-10-31 02:56:46
# 5            0.0  USGS  2024-10-31 13:01:07
# 6            0.0  USGS  2024-10-31 13:01:07
# 7            0.0  USGS  2024-10-31 17:16:18
# 8            0.0  USGS  2024-10-31 17:16:18
# 9            0.0  USGS  2024-10-31 17:41:23
# 10           0.0  USGS  2024-10-31 17:36:03
# 11           0.0  USGS  2024-10-30 18:31:02
# 12           0.0  USGS  2024-10-30 16:56:15
# 13           0.0  USGS  2024-10-30 16:56:15
# 14           0.0  USGS  2024-10-31 14:36:13
# 15           0.0  USGS  2024-10-31 14:36:13
# 16           0.0  USGS  2024-10-31 09:50:41
# 17           0.0  USGS  2024-10-31 09:50:41
# 18           0.0  USGS  2024-10-31 15:36:37
# 19           0.0  USGS  2024-10-31 15:36:37
#
#                                                   url  \
# 0   https://waterdata.usgs.gov/nwisweb/data/rating...
# 1   https://waterdata.usgs.gov/nwisweb/data/rating...
# 2   https://waterdata.usgs.gov/nwisweb/data/rating...
# 3   https://waterdata.usgs.gov/nwisweb/data/rating...
# 4   https://waterdata.usgs.gov/nwisweb/data/rating...
# 5   https://waterdata.usgs.gov/nwisweb/data/rating...
# 6   https://waterdata.usgs.gov/nwisweb/data/rating...
# 7   https://waterdata.usgs.gov/nwisweb/data/rating...
# 8   https://waterdata.usgs.gov/nwisweb/data/rating...
# 9   https://waterdata.usgs.gov/nwisweb/data/rating...
# 10  https://waterdata.usgs.gov/nwisweb/data/rating...
# 11  https://waterdata.usgs.gov/nwisweb/data/rating...
# 12  https://waterdata.usgs.gov/nwisweb/data/rating...
# 13  https://waterdata.usgs.gov/nwisweb/data/rating...
# 14  https://waterdata.usgs.gov/nwisweb/data/rating...
# 15  https://waterdata.usgs.gov/nwisweb/data/rating...
# 16  https://waterdata.usgs.gov/nwisweb/data/rating...
# 17  https://waterdata.usgs.gov/nwisweb/data/rating...
# 18  https://waterdata.usgs.gov/nwisweb/data/rating...
# 19  https://waterdata.usgs.gov/nwisweb/data/rating...
#
#      cwms_max_effective_date
# 0  2024-10-31 02:50:00+00:00
# 1  2024-10-31 02:50:00+00:00
# 2  2024-11-01 01:35:00+00:00
# 3  2024-11-01 01:35:00+00:00
# 4  2024-10-08 22:00:00+00:00
# 5  2024-10-31 23:00:00+00:00
# 6  2024-10-31 23:00:00+00:00
# 7  2024-11-01 03:15:00+00:00
# 8  2024-09-25 21:00:00+00:00
# 9  2024-11-01 03:40:00+00:00
# 10 2024-11-01 03:35:00+00:00
# 11 2024-10-31 04:30:00+00:00
# 12 2024-10-31 02:55:00+00:00
# 13 2024-10-31 02:55:00+00:00
# 14 2024-11-01 00:35:00+00:00
# 15 2024-11-01 00:35:00+00:00
# 16 2024-10-31 19:30:00+00:00
# 17 2024-10-22 21:15:00+00:00
# 18 2024-11-01 01:35:00+00:00
# 19 2024-11-01 01:35:00+00:00
#
# [20 rows x 24 columns]

# %%
def convert_tz(tz:str):
    if tz in ("AST","ADT"): tzid = "America/Halifax"
    elif tz in ("EST","EDT"): tzid = "US/Eastern"
    elif tz in ("CST","CDT"): tzid = "US/Central"
    elif tz in ("MST","MDT"): tzid = "US/Mountain"
    elif tz in ("PST","PDT"): tzid = "US/Pacific"
    elif tz in ("AKST","AKDT"): tzid = "America/Anchorage"
    elif tz in ("UTC","GMT"): tzid = "UTC"
    else: tzid = tz
    return tzid

# %%
def get_usgs_tz(data):
    line = data[data[0].str.startswith("# //STATION AGENCY=")].iloc[0,0]
    timezone = line.split("TIME_ZONE=")[1].split()[0].replace('"', '')
    timezone = convert_tz(timezone)
    return timezone

# %%
def get_begin_with_date(data,str_starts):
    date_string = None
    lines = data[data[0].str.startswith(str_starts)]
    for _, line in lines.iterrows():
        timestr = line[0].split("BEGIN=")[1].split()[0].strip().replace('"', '')
        if timestr.isdigit(): date_string = timestr
    return date_string

# %%
def get_usgs_effective_date(data,rating_type):

    date_string = None
    if rating_type == 'EXSA':
        line = data[data[0].str.startswith("# //RATING SHIFTED=")].iloc[0,0]  
        rating_shifted_date = line.split('=')[1].replace('"', '')
        date_string = rating_shifted_date.split()[0]

    elif rating_type == 'BASE':
        date_string = get_begin_with_date(data, ("# //RATING_DATETIME BEGIN="))

    elif rating_type == 'CORR':
        date_string = get_begin_with_date(data, ("# //CORR1_PREV BEGIN=","# //CORR2_PREV BEGIN=","# //CORR3_PREV BEGIN="))
        
    if date_string is None:
        line = data[data[0].str.startswith("# //RETRIEVED:")].iloc[0,0]
        date_string = line.split('RETRIEVED: ')[1]
        
    timezone = get_usgs_tz(data)   
    dt = pd.to_datetime(date_string).tz_localize(timezone).floor('Min')
    return dt

# %%
def convert_usgs_rating_df(df, rating_type):
    if rating_type == 'CORR':
        df = df.groupby("CORR")
        df = pd.concat([df.first(),df.last()], ignore_index=True, join="inner")
        df = df.sort_values(by=['INDEP'],ignore_index=True)
    df = df.rename(columns={"INDEP": "ind", "CORRINDEP": "dep", "DEP":"dep"})
    df_out = df[['ind', 'dep']].copy()
    return df_out

# %%
rating_units={'EXSA':'ft;cfs','BASE':'ft;cfs','CORR':'ft;ft'}
for _, row in updated_ratings.iterrows():
    print(f'Getting data for rating ID = {row["rating-id"]}')
    print(f'Getting data from USGS for USGS ID = {row["USGS_St_Num"]}, Rating Type = {row["rating-type"]}')
    usgs_rating, meta = nwis.get_ratings(site=row['USGS_St_Num'], file_type=str(row['rating-type']).lower())
    url = meta.url
    print(row['rating-id'])
    if usgs_rating.empty:
        print("Empty rating obtained from USGS Rating Curve not saved")
    else: 
        response = requests.get(url)
        temp = pd.DataFrame(response.text.split('\n'))
        usgs_effective_date = get_usgs_effective_date(temp,row['rating-type'])
        cwms_effective_date = row['cwms_max_effective_date']
        if (cwms_effective_date == usgs_effective_date) or (cwms_effective_date == (usgs_effective_date + timedelta(hours=1))):
            print("Effective dates are the same rating curve will not be saved")
        else:
            print(f"cwms = {cwms_effective_date}, usgs = {usgs_effective_date}")
            usgs_store_rating = convert_usgs_rating_df(usgs_rating,row['rating-type'])
            #find out how to get units
            if row['auto-migrate-extension']:
                current_rating = cwms.get_ratings(
                                        rating_id=row['rating-id'],
                                        office_id=row['office-id'],
                                        begin=cwms_effective_date,
                                        end=cwms_effective_date,
                                        method="EAGER",
                                        single_rating_df=True)
                rating_json = current_rating.json
                points_json = loads(usgs_store_rating.to_json(orient="records"))
                rating_json["simple-rating"]["rating-points"] = {"point": points_json}
                rating_json["simple-rating"]["effective-date"] = usgs_effective_date.isoformat()
                del rating_json["simple-rating"]["create-date"]
                rating_json["simple-rating"]["active"] = row['auto-activate']
            else:
                rating_json = cwms.rating_simple_df_to_json(data=usgs_store_rating,rating_id=row['rating-id'],office_id=row['office-id'],units=rating_units[row['rating-type']],effective_date=usgs_effective_date,active=row['auto-activate'])
            response = cwms.update_ratings(data = rating_json, rating_id = row['rating-id'])
            print(f'Stored rating for rating id = {row["rating-id"]}, effective date = {usgs_effective_date}')
        print(url)
# Out:
# Getting data for rating ID = AGYM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05087500, Rating Type = EXSA
# AGYM5.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05087500&file_type=exsa
# Getting data for rating ID = AGYM5.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05087500, Rating Type = CORR
# AGYM5.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05087500&file_type=corr
# Getting data for rating ID = BRMN8.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05055400, Rating Type = EXSA
# BRMN8.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05055400&file_type=exsa
# Getting data for rating ID = BRMN8.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05055400, Rating Type = CORR
# BRMN8.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05055400&file_type=corr
# Getting data for rating ID = DBCN8.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05057200, Rating Type = CORR
# DBCN8.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05057200&file_type=corr
# Getting data for rating ID = DDGW3.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05379500, Rating Type = EXSA
# DDGW3.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05379500&file_type=exsa
# Getting data for rating ID = DDGW3.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05379500, Rating Type = CORR
# DDGW3.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05379500&file_type=corr
# Getting data for rating ID = FSHM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05080000, Rating Type = EXSA
# FSHM5.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05080000&file_type=exsa
# Getting data for rating ID = FSHM5.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05080000, Rating Type = CORR
# FSHM5.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05080000&file_type=corr
# Getting data for rating ID = HRCN8.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05059300, Rating Type = EXSA
# HRCN8.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05059300&file_type=exsa
# Getting data for rating ID = HRCN8.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05059300, Rating Type = CORR
# HRCN8.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05059300&file_type=corr
# Getting data for rating ID = HUSM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05385500, Rating Type = EXSA
# HUSM5.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05385500&file_type=exsa
# Getting data for rating ID = LKBM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05094000, Rating Type = EXSA
# LKBM5.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05094000&file_type=exsa
# Getting data for rating ID = LKBM5.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05094000, Rating Type = CORR
# LKBM5.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05094000&file_type=corr
# Getting data for rating ID = Orwell_Dam-Tailwater.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05046000, Rating Type = EXSA
# Orwell_Dam-Tailwater.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05046000&file_type=exsa
# Getting data for rating ID = Orwell_Dam-Tailwater.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05046000, Rating Type = CORR
# Orwell_Dam-Tailwater.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05046000&file_type=corr
# Getting data for rating ID = SRGM5.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05106000, Rating Type = EXSA
# SRGM5.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05106000&file_type=exsa
# Getting data for rating ID = SRGM5.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05106000, Rating Type = CORR
# SRGM5.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05106000&file_type=corr
# Getting data for rating ID = WFON8.Stage;Flow.USGS-EXSA.USGS-NWIS
# Getting data from USGS for USGS ID = 05059480, Rating Type = EXSA
# WFON8.Stage;Flow.USGS-EXSA.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05059480&file_type=exsa
# Getting data for rating ID = WFON8.Stage;Stage.USGS-CORR.USGS-NWIS
# Getting data from USGS for USGS ID = 05059480, Rating Type = CORR
# WFON8.Stage;Stage.USGS-CORR.USGS-NWIS
#  effective date the same rating will not be updated
# https://nwis.waterdata.usgs.gov/nwisweb/get_ratings/?site_no=05059480&file_type=corr

# %%
rating_units = {'EXSA':'ft;cfs','BASE':'ft;cfs','CORR':'ft;ft'}

# %%
rating_units['EXSA']
# Out:
# 'ft;cfs'
